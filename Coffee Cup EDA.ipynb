# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("C:\\Users\\91988\\Downloads\\Coffee Cup Data.xlsx")
df.head()
# Out:
#    Profit  Margin  Sales  Cost of Goods Sold  Total Expenses  Marketing  \
# 0    -354    -245     17                 245             126         93
# 1    -172     -44     61                 105             128         95
# 2    -117     -26    118                 144              91         47
# 3    -113     -27    180                 207              86         64
# 4     -40      11     99                  88              51         27
#
#    Inventory  Budget Profit  Budget Margin  Budget Sales  Budget COGS  \
# 0       1419           -240           -160             0          160
# 1        725           -170            -50            50          100
# 2        862           -120            -40           140          180
# 3        965            -70            -10           140          150
# 4        525            -30             10            80           70
#
#         Date    Market          Province           City  Store#   Market Size  \
# ...

# %%
df.dtypes
# Out:
# Profit                 int64
# Margin                 int64
# Sales                  int64
# Cost of Goods Sold     int64
# Total Expenses         int64
# Marketing              int64
# Inventory              int64
# Budget Profit          int64
# Budget Margin          int64
# Budget Sales           int64
# Budget COGS            int64
# Date                  object
# Market                object
# Province              object
# City                  object
# Store#                 int64
# Market Size           object
# Product Type          object
# Product               object
# Type                  object
# dtype: object

# %%
df["Type"].unique()
# Out:
# array(['Regular', 'Decaf'], dtype=object)

# %%
df["Product"].unique()
# Out:
# array(['Green Tea', 'Caffe Mocha', 'Decaf Irish Cream', 'Mint', 'Lemon',
#        'Chamomile', 'Darjeeling', 'Earl Grey', 'Caffe Latte',
#        'Regular Espresso', 'Colombian', 'Amaretto', 'Decaf Espresso'],
#       dtype=object)

# %%
df["Product Type"].unique()
# Out:
# array(['Tea', 'Espresso', 'Coffee', 'Herbal Tea'], dtype=object)

# %%
df["Market Size"].unique()
# Out:
# array(['Small Market', 'Major Market'], dtype=object)

# %%
df["Market"].unique()
# Out:
# array(['Central', 'Atlantic', 'West', 'North', 'Prairie'], dtype=object)

# %%
df["Date"].unique()
# Out:
# array(['31/1/2019', '28/2/2019', '31/03/2012', '31/03/2019', '30/04/2019',
#        '31/05/2019', '30/06/2019', '31/07/2019', '31/08/2019',
#        '30/09/2019', '31/10/2019', '30/11/2019', '31/12/2019',
#        '31/01/2020', '28/02/2020', '31/03/2020', '30/04/2020',
#        '31/05/2020', '30/06/2020', '31/07/2020', '31/08/2020',
#        '30/09/2020', '31/10/2020', '30/11/2020', '31/12/2020'],
#       dtype=object)

# %%
df[df["Date"] == '31/03/2012']
# Out:
#      Profit  Margin  Sales  Cost of Goods Sold  Total Expenses  Marketing  \
# 354    -340    -245     32                 245             127         93
# 355    -208     -62     63                 125             146        113
#
#      Inventory  Budget Profit  Budget Margin  Budget Sales  Budget COGS  \
# 354       2449           -240           -160             0          160
# 355       1118           -190            -60            60          120
#
#            Date    Market Province        City  Store#   Market Size  \
# 354  31/03/2012   Central  Ontario      London     775  Small Market
# 355  31/03/2012  Atlantic      PEI  Summerside     607  Major Market
#
#     Product Type      Product     Type
# 354          Tea    Green Tea  Regular
# 355     Espresso  Caffe Mocha  Regular

# %%
df["Profit"].max()
# Out:
# 778

# %%
df["Profit"].min()
# Out:
# -638

# %%
df["Profit"].mean()
# Out:
# 61.097693032015066

# %%
df.describe(include= "all")
# Out:
#              Profit       Margin        Sales  Cost of Goods Sold  \
# count   4248.000000  4248.000000  4248.000000         4248.000000
# unique          NaN          NaN          NaN                 NaN
# top             NaN          NaN          NaN                 NaN
# freq            NaN          NaN          NaN                 NaN
# mean      61.097693   104.293315   192.987524           84.433145
# std      101.708546    94.342522   151.133127           67.249769
# min     -638.000000  -302.000000    17.000000            0.000000
# 25%       17.000000    52.750000   100.000000           43.000000
# 50%       40.000000    76.000000   138.000000           60.000000
# 75%       92.000000   132.000000   230.000000          100.000000
# max      778.000000   613.000000   912.000000          364.000000
#
#         Total Expenses    Marketing    Inventory  Budget Profit  \
# count      4248.000000  4248.000000  4248.000000    4248.000000
# ...

# %%
df.isnull().sum()
# Out:
# Profit                0
# Margin                0
# Sales                 0
# Cost of Goods Sold    0
# Total Expenses        0
# Marketing             0
# Inventory             0
# Budget Profit         0
# Budget Margin         0
# Budget Sales          0
# Budget COGS           0
# Date                  0
# Market                0
# Province              0
# City                  0
# Store#                0
# Market Size           0
# Product Type          0
# Product               0
# Type                  0
# dtype: int64

# %% [markdown]
# ## Date

# %%
#dropping 354 and 355 rows

df.drop([354,355], inplace = True)

# %%
df[df["Date"] == '31/03/2012']
# Out:
# Empty DataFrame
# Columns: [Profit, Margin, Sales, Cost of Goods Sold, Total Expenses, Marketing, Inventory, Budget Profit, Budget Margin, Budget Sales, Budget COGS, Date, Market, Province, City, Store#, Market Size, Product Type, Product, Type]
# Index: []

# %%
display(df.iloc[354])
# Out:
# Profit                             -121
# Margin                              -27
# Sales                               127
# Cost of Goods Sold                  154
# Total Expenses                       94
# Marketing                            50
# Inventory                          1288
# Budget Profit                      -120
# Budget Margin                       -40
# Budget Sales                        150
# Budget COGS                         190
# Date                         31/03/2019
# Market                             West
# Province               British Columbia
# City                          Vancouver
# Store#                              685
# Market Size                Major Market
# Product Type                     Coffee
# Product               Decaf Irish Cream
# Type                              Decaf
# Name: 356, dtype: object

# %%
display(df.iloc[355])
# Out:
# Profit                        -119
# Margin                         -32
# Sales                          182
# Cost of Goods Sold             214
# Total Expenses                  87
# Marketing                       66
# Inventory                     1480
# Budget Profit                  -80
# Budget Margin                  -20
# Budget Sales                   140
# Budget COGS                    160
# Date                    31/03/2019
# Market                    Atlantic
# Province                       PEI
# City                    Summerside
# Store#                         914
# Market Size           Major Market
# Product Type            Herbal Tea
# Product                       Mint
# Type                         Decaf
# Name: 357, dtype: object

# %%
df = df.reset_index(drop = True)

# %%
display(df.iloc[354])
# Out:
# Profit                             -121
# Margin                              -27
# Sales                               127
# Cost of Goods Sold                  154
# Total Expenses                       94
# Marketing                            50
# Inventory                          1288
# Budget Profit                      -120
# Budget Margin                       -40
# Budget Sales                        150
# Budget COGS                         190
# Date                         31/03/2019
# Market                             West
# Province               British Columbia
# City                          Vancouver
# Store#                              685
# Market Size                Major Market
# Product Type                     Coffee
# Product               Decaf Irish Cream
# Type                              Decaf
# Name: 354, dtype: object

# %%
display(df.iloc[355])
# Out:
# Profit                        -119
# Margin                         -32
# Sales                          182
# Cost of Goods Sold             214
# Total Expenses                  87
# Marketing                       66
# Inventory                     1480
# Budget Profit                  -80
# Budget Margin                  -20
# Budget Sales                   140
# Budget COGS                    160
# Date                    31/03/2019
# Market                    Atlantic
# Province                       PEI
# City                    Summerside
# Store#                         914
# Market Size           Major Market
# Product Type            Herbal Tea
# Product                       Mint
# Type                         Decaf
# Name: 355, dtype: object

# %%
df.head()
# Out:
#    Profit  Margin  Sales  Cost of Goods Sold  Total Expenses  Marketing  \
# 0    -354    -245     17                 245             126         93
# 1    -172     -44     61                 105             128         95
# 2    -117     -26    118                 144              91         47
# 3    -113     -27    180                 207              86         64
# 4     -40      11     99                  88              51         27
#
#    Inventory  Budget Profit  Budget Margin  Budget Sales  Budget COGS  \
# 0       1419           -240           -160             0          160
# 1        725           -170            -50            50          100
# 2        862           -120            -40           140          180
# 3        965            -70            -10           140          150
# 4        525            -30             10            80           70
#
#         Date    Market          Province           City  Store#   Market Size  \
# ...

# %% [markdown]
# ## Market

# %%
df[df["Market"] == 'North']
# Out:
#       Profit  Margin  Sales  Cost of Goods Sold  Total Expenses  Marketing  \
# 6        -39      11     99                  88              50         27
# 8        -11      53     90                  37              64         34
# 11       -10      53     90                  37              63         34
# 13        -9      36     65                  29              45         11
# 15        -8      36     65                  29              44         11
# ...      ...     ...    ...                 ...             ...        ...
# 4175      53      76    148                  63              40         19
# 4176      55      75    135                  52              38         16
# 4178      68      71    128                  49              25         13
# 4185      71      73    131                  50              25         14
# 4205     114     120    228                  94              43         31
#
# ...

# %%
df[df["Market"] == 'Prairie']
# Out:
#       Profit  Margin  Sales  Cost of Goods Sold  Total Expenses  Marketing  \
# 20         0      87    150                  63              87         57
# 26         7     105    180                  75              98         68
# 35         9     111    190                  79             102         72
# 50        13      66    120                  54              53         20
# 54        17      72    130                  58              55         22
# ...      ...     ...    ...                 ...             ...        ...
# 4214     156     174    308                 115              69         37
# 4221     181     186    341                 134              64         41
# 4223     197     179    322                 123              46         34
# 4226     199     179    322                 123              45         34
# 4232     279     284    559                 241              96         74
#
# ...

# %%
df[df["Market"]== "Central"]
# Out:
#       Profit  Margin  Sales  Cost of Goods Sold  Total Expenses  Marketing  \
# 0       -354    -245     17                 245             126         93
# 18        -3      42     76                  34              45         12
# 22         1      87    150                  63              86         57
# 24         4      34     62                  28              30          8
# 38        10      27     45                  18              17          5
# ...      ...     ...    ...                 ...             ...        ...
# 4231     233     251    534                 250              94         70
# 4234     288     310    569                 224             116         73
# 4235     288     310    569                 224             116         73
# 4236     319     329    614                 247             114         81
# 4240     321     329    614                 247             113         81
#
# ...

# %%
df[df["Market"]== "Atlantic"]
# Out:
#       Profit  Margin  Sales  Cost of Goods Sold  Total Expenses  Marketing  \
# 1       -172     -44     61                 105             128         95
# 3       -113     -27    180                 207              86         64
# 4        -40      11     99                  88              51         27
# 5        -39      11     99                  88              50         27
# 7        -23      63    126                  63              86         57
# ...      ...     ...    ...                 ...             ...        ...
# 4239     321     360    697                 294             144        111
# 4242     402     420    745                 279             149         97
# 4243     459     453    796                 294             144        111
# 4244     463     407    700                 250              95         70
# 4245     579     443    543                  67              53         22
#
# ...

# %%
df[df["Market"]=="West"]
# Out:
#       Profit  Margin  Sales  Cost of Goods Sold  Total Expenses  Marketing  \
# 2       -117     -26    118                 144              91         47
# 19        -2      50    145                  95              52         30
# 21         0      87    150                  63              87         57
# 51        16      72    130                  58              56         22
# 55        17     145    250                 105             128         95
# ...      ...     ...    ...                 ...             ...        ...
# 4227     199     179    322                 123              45         34
# 4229     233     251    534                 250              94         70
# 4233     279     284    559                 241              96         74
# 4237     321     329    614                 247             113         81
# 4241     402     420    745                 279             149         97
#
# ...

# %% [markdown]
# # Province

# %%
df["Province"].unique()
# Out:
# array(['Ontario', 'PEI', 'British Columbia', 'New Brunswick', 'Nunavut',
#        'Newfoundland', 'Northwest Territories', 'Alberta', 'Nova Scotia',
#        'Manitoba', 'Yukon', 'Saskatchewan', 'Quebec'], dtype=object)

# %%
len(df[df["Province"]=="Ontario"])
# Out:
# 527

# %%
#Number of stores in PEI province

len(df[df["Province"]=="PEI"])
# Out:
# 191

# %%
#Number of stores in "British Columbia" province

len(df[df["Province"]=="British Columbia"])
# Out:
# 504

# %%
#Number of stores in "New Brunswick" province

len(df[df["Province"]=="New Brunswick"])
# Out:
# 456

# %%
#Number of stores in "Nunavut" province

len(df[df["Province"]=="Nunavut"])
# Out:
# 216

# %%
#Number of stores in "Newfoundland" province

len(df[df["Province"]=="Newfoundland"])
# Out:
# 360

# %%
#Number of stores in "Northwest Territories" province

len(df[df["Province"]=="Northwest Territories"])
# Out:
# 168

# %%
#Number of stores in "Alberta" province

len(df[df["Province"]=="Alberta"])
# Out:
# 432

# %%
#Number of stores in "Nova Scotia" province

len(df[df["Province"]=="Nova Scotia"])
# Out:
# 456

# %%
#Number of stores in "Manitoba" province

len(df[df["Province"]=="Manitoba"])
# Out:
# 168

# %%
#Number of stores in "Yukon" province

len(df[df["Province"]=="Yukon"])
# Out:
# 168

# %%
#Number of stores in "Saskatchewan" province

len(df[df["Province"]=="Saskatchewan"])
# Out:
# 216

# %%
#Number of stores in "Quebec" province

len(df[df["Province"]=="Quebec"])
# Out:
# 384

# %% [markdown]
# # Store Number

# %%
df["Store#"].unique()
# Out:
# array([ 702,  315,  685,  845,  591,  505,  314, 2001,  573, 4001,  417,
#         303,  670,  541,  775, 6300, 1001, 2500, 6520,  504,  239,  580,
#        6000,  918,  503,  971,  405,  954,  754,  985,  225,  404,  863,
#         337,  636,  772,  660,  217,  347,  708,  630,  309,  646,  312,
#         773,  607,  631,  716,  585,  318,  816,  727,  305,  350,  786,
#         850,  407,  847,  518,  815,  917,  914,  550,  598,  941,  813,
#         561,  321,  224,  516,  965,  718,  904, 2900,  690,  212,  618,
#         352,  370, 6200,  386, 2850, 2050, 1200, 4200,  620, 4500,  450,
#        2300,  510,  635,  599, 1250,  915,  480,  525,  640, 1401, 4700,
#        2370,  535,  900], dtype=int64)

# %% [markdown]
# # City

# %%
len(df['City'].unique())
# Out:
# 51

# %%
t=df.groupby(['Market','Province','City','Store#','Product Type'])['Product'].count().reset_index()
t
# Out:
#        Market          Province        City  Store# Product Type  Product
# 0    Atlantic     New Brunswick    Bathurst     580       Coffee       16
# 1    Atlantic     New Brunswick    Bathurst     580     Espresso       25
# 2    Atlantic     New Brunswick    Bathurst     580   Herbal Tea       17
# 3    Atlantic     New Brunswick  Fredricton     550       Coffee       18
# 4    Atlantic     New Brunswick  Fredricton     550     Espresso       23
# ..        ...               ...         ...     ...          ...      ...
# 657      West  British Columbia   Vancouver     685          Tea       10
# 658      West  British Columbia    Victoria     690       Coffee       15
# 659      West  British Columbia    Victoria     690     Espresso       15
# 660      West  British Columbia    Victoria     690   Herbal Tea       15
# 661      West  British Columbia    Victoria     690          Tea       17
#
# [662 rows x 6 columns]

# %%
t1=df.groupby(['Store#','Product Type'])['Product'].count().reset_index()
t1
# Out:
#      Store# Product Type  Product
# 0       212     Espresso        5
# 1       212   Herbal Tea        2
# 2       212          Tea        5
# 3       217       Coffee        5
# 4       217     Espresso        3
# ..      ...          ...      ...
# 383    6300          Tea       18
# 384    6520       Coffee        8
# 385    6520     Espresso       13
# 386    6520   Herbal Tea        8
# 387    6520          Tea       12
#
# [388 rows x 3 columns]

# %%
len(df['Store#'].unique())
# Out:
# 102

# %%
df['Margin Corrected']=df['Sales']-df['Cost of Goods Sold']

# %%
df['Margin']
# Out:
# 0      -245
# 1       -44
# 2       -26
# 3       -27
# 4        11
#        ...
# 4241    420
# 4242    420
# 4243    453
# 4244    407
# 4245    443
# Name: Margin, Length: 4246, dtype: int64

# %%
df["Margin Corrected"]
# Out:
# 0      -228
# 1       -44
# 2       -26
# 3       -27
# 4        11
#        ...
# 4241    466
# 4242    466
# 4243    502
# 4244    450
# 4245    476
# Name: Margin Corrected, Length: 4246, dtype: int64

# %%
df["Profit Corrected"] = df['Margin Corrected'] - df['Total Expenses']

# %%
df['Profit']
# Out:
# 0      -354
# 1      -172
# 2      -117
# 3      -113
# 4       -40
#        ...
# 4241    402
# 4242    402
# 4243    459
# 4244    463
# 4245    579
# Name: Profit, Length: 4246, dtype: int64

# %%
df["Profit Corrected"]
# Out:
# 0      -354
# 1      -172
# 2      -117
# 3      -113
# 4       -40
#        ...
# 4241    317
# 4242    317
# 4243    358
# 4244    355
# 4245    423
# Name: Profit Corrected, Length: 4246, dtype: int64

# %%
df.head()
# Out:
#    Profit  Margin  Sales  Cost of Goods Sold  Total Expenses  Marketing  \
# 0    -354    -245     17                 245             126         93
# 1    -172     -44     61                 105             128         95
# 2    -117     -26    118                 144              91         47
# 3    -113     -27    180                 207              86         64
# 4     -40      11     99                  88              51         27
#
#    Inventory  Budget Profit  Budget Margin  Budget Sales  ...    Market  \
# 0       1419           -240           -160             0  ...   Central
# 1        725           -170            -50            50  ...  Atlantic
# 2        862           -120            -40           140  ...      West
# 3        965            -70            -10           140  ...  Atlantic
# 4        525            -30             10            80  ...  Atlantic
#
#            Province           City Store#   Market Size  Product Type  \
# ...

# %%
#Creating new column for date in correct datetime format

df['Date Corrected'] = pd.to_datetime(df['Date'])

# %%
df.head()
# Out:
#    Profit  Margin  Sales  Cost of Goods Sold  Total Expenses  Marketing  \
# 0    -354    -245     17                 245             126         93
# 1    -172     -44     61                 105             128         95
# 2    -117     -26    118                 144              91         47
# 3    -113     -27    180                 207              86         64
# 4     -40      11     99                  88              51         27
#
#    Inventory  Budget Profit  Budget Margin  Budget Sales  ...  \
# 0       1419           -240           -160             0  ...
# 1        725           -170            -50            50  ...
# 2        862           -120            -40           140  ...
# 3        965            -70            -10           140  ...
# 4        525            -30             10            80  ...
#
#            Province           City Store#   Market Size Product Type  \
# 0           Ontario       Toronto     702  Small Market          Tea
# ...

# %%
df.dtypes
# Out:
# Profit                         int64
# Margin                         int64
# Sales                          int64
# Cost of Goods Sold             int64
# Total Expenses                 int64
# Marketing                      int64
# Inventory                      int64
# Budget Profit                  int64
# Budget Margin                  int64
# Budget Sales                   int64
# Budget COGS                    int64
# Date                          object
# Market                        object
# Province                      object
# City                          object
# Store#                         int64
# Market Size                   object
# Product Type                  object
# Product                       object
# Type                          object
# Margin Corrected               int64
# Profit Corrected               int64
# Date Corrected        datetime64[ns]
# dtype: object

# %%
df.to_csv("Coffee Cup1.csv")
